# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = [45,40,55,60,65,35]
df = pd.DataFrame(data)
df
# Out:
#     0
# 0  45
# 1  40
# 2  55
# 3  60
# 4  65
# 5  35

# %%
print(np.mean(data))#mean関数
# Out:
# 50.0

# %%
print(df.mean())#meanメソッド
# Out:
# 0    50.0
# dtype: float64

# %%
#偏差の和
sum_deviation = sum([x - mean for x in data])
print("偏差の和:", sum_deviation)
# Out:
# 偏差の和: 0.0

# %%
#平方和
l = []
for x in data:
    l.append((x - np.mean(data)) ** 2)
print("平方和:",sum(l))
# Out:
# 平方和: 700.0

# %%
#分散
print(np.var(data))#var関数
print(df.var(ddof=0))#varメソッド
# Out:
# 116.66666666666667
# 0    116.666667
# dtype: float64

# %%
#標準偏差
print("numpyの標準偏差",np.std(data))#std関数
print("pandasの標準偏差",df.std(ddof=0))#stdメソッド
# Out:
# numpyの標準偏差 10.801234497346433
# pandasの標準偏差 0    10.801234
# dtype: float64

# %%
#変動係数
std = np.std(data)
cv = std / mean 
print("平均:",mean)
print("標準偏差:",std)
print("変動係数:",cv)
# Out:
# 平均: 50.0
# 標準偏差: 10.801234497346433
# 変動係数: 0.21602468994692867

# %%
#問3
import numpy as np
avg_a = 40
std_a = 10
avg_b = 90
std_b = 20
CV_A = stdA / avgA
CV_B = stdB / avgB
print(CV_A)
print(CV_B)
CV_A > CV_B
# Out:
# 0.25
# 0.2222222222222222
# True
