# %% [markdown]
# ## データの取り込みと確認

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import japanize_matplotlib
import seaborn as sns
import pandas as pd
import numpy as np
sns.set(font = "IPAexGothic", style = "white") #グラフのプロパティを設定
plt.rcParams["figure.figsize"] = [10, 5] #グラフの大きさを設定
pd.set_option('display.max_columns', 150) #表示する列数の上限を150に設定
pd.set_option('display.max_rows', 50) #表示する行数の上限を50に設定

# %%
# データの取り込み
df_master = pd.read_csv("advertising_analysis_data.csv",parse_dates=True,index_col="date")
df = df_master.copy()
display(df.sort_index().head(20))
display(df.sort_index().tail(20))
# Out:
#             productA_sales_amount  productB_sales_amount  productA_ad_cost  \
# date
# 2021-09-01                1927502                    NaN      23441.907672
# 2021-09-02                1504470                    NaN      15493.743139
# 2021-09-03                2335190                    NaN      20552.312426
# 2021-09-04                2453752                    NaN      19648.972397
# 2021-09-05                2705950                    NaN      18834.571127
# 2021-09-06                2527534                    NaN      19787.651347
# 2021-09-07                2263692                    NaN      23754.371125
# 2021-09-08                2646010                    NaN      27970.558881
# 2021-09-09                2114339                    NaN      27112.562260
# 2021-09-10                2326950                    NaN      23531.047385
# 2021-09-11                2782640                    NaN      31281.112178
# 2021-09-12                2928070                    NaN      29754.791593
# 2021-09-13                4005309                    NaN      25775.823601
# 2021-09-14                3130552                    NaN      28797.496225
# 2021-09-15                2381450                    NaN      27606.645370
# 2021-09-16                2563646                    NaN      27688.678330
# 2021-09-17                2677370                    NaN      28233.475717
# 2021-09-18                3182840                    NaN      26606.125813
# 2021-09-19                2840650                    NaN      27229.898854
# 2021-09-20                3573850                    NaN      26678.517887
#
#             productB_ad_cost
# date
# 2021-09-01               NaN
# 2021-09-02               NaN
# 2021-09-03               NaN
# 2021-09-04               NaN
# 2021-09-05               NaN
# 2021-09-06               NaN
# 2021-09-07               NaN
# 2021-09-08               NaN
# 2021-09-09               NaN
# 2021-09-10               NaN
# 2021-09-11               NaN
# 2021-09-12               NaN
# 2021-09-13               NaN
# 2021-09-14               NaN
# 2021-09-15               NaN
# 2021-09-16               NaN
# 2021-09-17               NaN
# 2021-09-18               NaN
# 2021-09-19               NaN
# 2021-09-20               NaN
#             productA_sales_amount  productB_sales_amount  productA_ad_cost  \
# date
# 2023-08-01                2049246               131760.0      24979.097464
# 2023-08-02                1967946                99090.0      23643.866522
# 2023-08-03                1761354               112080.0      26849.559270
# 2023-08-04                1784118                99200.0      19666.428332
# 2023-08-05                1981450               129880.0      32243.251313
# 2023-08-06                1840149               184880.0      28494.198973
# 2023-08-07                1372489               139930.0      33538.421873
# 2023-08-08                2126794               174030.0      35302.590253
# 2023-08-09                1592361               107720.0      27781.759488
# 2023-08-10                1948381               119480.0               NaN
# 2023-08-11                1653985                72930.0               NaN
# 2023-08-12                1321592               111380.0               NaN
# 2023-08-13                1985933                92590.0               NaN
# 2023-08-14                1620405                68440.0               NaN
# 2023-08-15                1826744                99640.0               NaN
# 2023-08-16                1544770                56780.0               NaN
# 2023-08-17                2247083               100480.0               NaN
# 2023-08-18                1617448               142840.0               NaN
# 2023-08-19                2455261                98500.0               NaN
# 2023-08-20                2222048               200700.0               NaN
#
#             productB_ad_cost
# date
# 2023-08-01      25981.597036
# 2023-08-02      23863.031057
# 2023-08-03      30837.610781
# 2023-08-04      26692.262709
# 2023-08-05      25540.293265
# 2023-08-06      26710.427325
# 2023-08-07      25327.308633
# 2023-08-08      24587.075621
# 2023-08-09      25550.264423
# 2023-08-10               NaN
# 2023-08-11               NaN
# 2023-08-12               NaN
# 2023-08-13               NaN
# 2023-08-14               NaN
# 2023-08-15               NaN
# 2023-08-16               NaN
# 2023-08-17               NaN
# 2023-08-18               NaN
# 2023-08-19               NaN
# 2023-08-20               NaN

# %% [markdown]
# infoメソッドやdescribeメソッドを使って、おかしなデータがないか確認する。

# %%
#データの欠損と型の確認(info)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 719 entries, 2022-03-02 to 2021-09-24
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   productA_sales_amount  719 non-null    int64
#  1   productB_sales_amount  627 non-null    float64
#  2   productA_ad_cost       708 non-null    float64
#  3   productB_ad_cost       519 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 28.1 KB

# %%
#データ要約確認(describe)
display(df.describe())
# Out:
#        productA_sales_amount  productB_sales_amount  productA_ad_cost  \
# count           7.190000e+02             627.000000        708.000000
# mean            2.343864e+06           85163.923445      33616.558932
# std             6.928987e+05           71152.123551      13196.077829
# min             7.000360e+05            5000.000000      12262.361659
# 25%             1.867512e+06           29200.000000      25912.259989
# 50%             2.272697e+06           68400.000000      33539.552686
# 75%             2.753353e+06          123800.000000      39817.050760
# max             5.291189e+06          676900.000000     144050.183923
#
#        productB_ad_cost
# count        519.000000
# mean       15230.276722
# std        12161.041701
# min            0.000000
# 25%         3986.500000
# 50%        10429.264000
# 75%        24720.040282
# max        50937.290199

# %% [markdown]
# ## 課題0. データを"日"単位から"週"単位に変換してみましょう

# %%
#欠損を0で補完し、日付順に並び替え
df_week = df[:'2023-08-05'].fillna(0).sort_index()


#集計単位を"週""
df_week = df_week.resample("W").sum()
df_week
# Out:
#             productA_sales_amount  productB_sales_amount  productA_ad_cost  \
# date
# 2021-09-05               10926864                    0.0      97971.506761
# 2021-09-12               17589235                    0.0     183192.094769
# 2021-09-19               20781817                    0.0     191938.143910
# 2021-09-26               20558966                    0.0     188632.747531
# 2021-10-03               21064521                    0.0     208946.035530
# ...                           ...                    ...               ...
# 2023-07-09               21325636              1227180.0     247862.272409
# 2023-07-16               16510745              1210950.0     217779.375201
# 2023-07-23               16171629              1041210.0     187925.309601
# 2023-07-30               14961084              1059920.0     180078.947083
# 2023-08-06               11305344               677600.0     150359.568958
#
#             productB_ad_cost
# date
# 2021-09-05          0.000000
# 2021-09-12          0.000000
# 2021-09-19          0.000000
# 2021-09-26          0.000000
# 2021-10-03          0.000000
# ...                      ...
# 2023-07-09     174727.431662
# 2023-07-16     142031.888091
# 2023-07-23     139343.290384
# 2023-07-30     167407.346049
# 2023-08-06     156707.295748
#
# [101 rows x 4 columns]

# %% [markdown]
# ## 課題1. 売上と広告費の推移から分かることはあるか？

# %% [markdown]
# productA,Bそれぞれの売り上げと広告費の折れ線グラフを作成、分析する

# %%
#productAとproductBのデータフレームを分けておく
df_A = df_week[["productA_sales_amount", "productA_ad_cost"]]
df_B = df_week[["productB_sales_amount", "productB_ad_cost"]]
display(df_A)
display(df_B)
# Out:
#             productA_sales_amount  productA_ad_cost
# date
# 2021-09-05               10926864      97971.506761
# 2021-09-12               17589235     183192.094769
# 2021-09-19               20781817     191938.143910
# 2021-09-26               20558966     188632.747531
# 2021-10-03               21064521     208946.035530
# ...                           ...               ...
# 2023-07-09               21325636     247862.272409
# 2023-07-16               16510745     217779.375201
# 2023-07-23               16171629     187925.309601
# 2023-07-30               14961084     180078.947083
# 2023-08-06               11305344     150359.568958
#
# [101 rows x 2 columns]
#             productB_sales_amount  productB_ad_cost
# date
# 2021-09-05                    0.0          0.000000
# 2021-09-12                    0.0          0.000000
# 2021-09-19                    0.0          0.000000
# 2021-09-26                    0.0          0.000000
# 2021-10-03                    0.0          0.000000
# ...                           ...               ...
# 2023-07-09              1227180.0     174727.431662
# 2023-07-16              1210950.0     142031.888091
# 2023-07-23              1041210.0     139343.290384
# 2023-07-30              1059920.0     167407.346049
# 2023-08-06               677600.0     156707.295748
#
# [101 rows x 2 columns]

# %%
#productAをグラフ化
fig,axes = plt.subplots(2,1,tight_layout=True,sharex="all")
sns.lineplot(x=df_A.index,y=df_A["productA_sales_amount"],ax=axes[0])
sns.lineplot(x=df_A.index,y=df_A["productA_ad_cost"],ax=axes[1])
# Out:
# <Axes: xlabel='date', ylabel='productA_ad_cost'>

# %%
#productB
fig,axes = plt.subplots(2,1,tight_layout=True,sharex="all")
sns.lineplot(x=df_B.index,y=df_B["productB_sales_amount"],ax=axes[0])
sns.lineplot(x=df_B.index,y=df_B["productB_ad_cost"],ax=axes[1])
# Out:
# <Axes: xlabel='date', ylabel='productB_ad_cost'>

# %% [markdown]
# ## 課題2. 広告の即時効果はあるか？

# %% [markdown]
# ①広告費と売上の相関を検証→散布図の作成と、相関係数を算出
# ②ROASの算出→単回帰分析を使って回帰係数から算出(sklearnでも可能だが、statsmodelsがおすすめ)

# %%
# 相関分析
from scipy import stats

fig, axes = plt.subplots(1, 2, tight_layout=True)
sns.scatterplot(x="productA_ad_cost", y="productA_sales_amount", data=df_A, ax=axes[0])
sns.scatterplot(x="productB_ad_cost", y="productB_sales_amount", data=df_B, ax=axes[1])
print("productA:", stats.spearmanr(df_A["productA_ad_cost"], df_A["productA_sales_amount"]))
print("productB:", stats.spearmanr(df_B["productB_ad_cost"], df_B["productB_sales_amount"]))

#productA,Bどちらも同じ週の広告費と売上に中等度の相関がある。相関係数はBの方がやや高い。(相関の高さと効果の高さは別物なので注意)
# Out:
# productA: SignificanceResult(statistic=np.float64(0.5012580081537565), pvalue=np.float64(9.34036418096036e-08))
# productB: SignificanceResult(statistic=np.float64(0.6965090307068318), pvalue=np.float64(6.093874354602731e-16))

# %%
# 単回帰分析(productA)
import statsmodels.api as sm
X = df_A["productA_ad_cost"]
y = df_A["productA_sales_amount"]
model=sm.OLS(y,X)
result = model.fit()
result.summary()


# # 単回帰分析(productA)
# import statsmodels.api as sm
# X = df_A["productA_ad_cost"]
# y = df_A["productA_sales_amount"]
# model=sm.OLS(y, X)
# result = model.fit()
# result.summary()

#回帰係数は65であり、ROASは6500%(1円の広告費に対して65円の売上)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     productA_sales_amount   R-squared (uncentered):                   0.908
# Model:                               OLS   Adj. R-squared (uncentered):              0.907
# Method:                    Least Squares   F-statistic:                              988.1
# Date:                   Wed, 19 Nov 2025   Prob (F-statistic):                    1.23e-53
# Time:                           19:12:03   Log-Likelihood:                         -1703.4
# No. Observations:                    101   AIC:                                      3409.
# Df Residuals:                        100   BIC:                                      3411.
# Df Model:                              1
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# productA_ad_cost    64.9107      2.065     31.433      0.000      60.814      69.008
# ==============================================================================
# Omnibus:                       58.912   Durbin-Watson:                   0.636
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              345.991
# Skew:                          -1.780   Prob(JB):                     7.40e-76
# Kurtosis:                      11.339   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#単回帰分析(productB)
import statsmodels.api as sm

X = df_B["productB_ad_cost"]
y = df_B["productB_sales_amount"]
model = sm.OLS(y,X)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     productB_sales_amount   R-squared (uncentered):                   0.741
# Model:                               OLS   Adj. R-squared (uncentered):              0.738
# Method:                    Least Squares   F-statistic:                              285.4
# Date:                   Wed, 19 Nov 2025   Prob (F-statistic):                    4.64e-31
# Time:                           20:21:37   Log-Likelihood:                         -1430.5
# No. Observations:                    101   AIC:                                      2863.
# Df Residuals:                        100   BIC:                                      2866.
# Df Model:                              1
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# productB_ad_cost     5.0440      0.299     16.895      0.000       4.452       5.636
# ==============================================================================
# Omnibus:                       17.323   Durbin-Watson:                   0.631
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.813
# Skew:                           0.887   Prob(JB):                     1.83e-05
# Kurtosis:                       4.427   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## 課題3. 広告の翌週以降への効果はあるか？

# %%
#定常性の確認(ADF検定)
from statsmodels.tsa.stattools import adfuller

for i in range(len(df_A.columns)):
    c_results = adfuller(df_A.iloc[:, i], regression="c")
    print(df_A.columns[i], c_results[1])
for i in range(len(df_B.columns)):
    c_results = adfuller(df_B.iloc[:, i], regression="c")
    print(df_B.columns[i], c_results[1])

# どれも0.05以下なため、定常性は確保されていると判断する(確保されていない場合は前週値との差分を使ったりする必要がある)
# Out:
# productA_sales_amount 0.002030191787788228
# productA_ad_cost 0.008748934088857829
# productB_sales_amount 0.010577681167043577
# productB_ad_cost 0.31902087898069387

# %%
#VAR+グレンジャー因果性検定(productA)
from statsmodels.tsa.vector_ar.var_model import VAR
#VAR+グレンジャー因果性検定(productA)
from statsmodels.tsa.vector_ar.var_model import VAR

#VAR
df = df_A[["productA_sales_amount", "productA_ad_cost"]]
maxlags = 5
var_model = VAR(df)
lag = var_model.select_order(maxlags).selected_orders
print("selectラグ", lag["aic"])
results = var_model.fit(lag["aic"])
print(results.summary())

# グレンジャー因果性検定
test_results = results.test_causality(causing=1, caused=0)
print("グレンジャー因果性検定：", df.columns[1], "->", df.columns[0], test_results.pvalue)

#productAの広告の翌週以降の効果はなさそう
# Out:
# selectラグ 3
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 20, Nov, 2025
# Time:                     09:20:03
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    51.6594
# Nobs:                     98.0000    HQIC:                   51.4395
# Log likelihood:          -2777.33    FPE:                1.88469e+22
# AIC:                      51.2901    Det(Omega_mle):     1.64178e+22
# --------------------------------------------------------------------
# Results for equation productA_sales_amount
# ===========================================================================================
#                               coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------
# const                      3910421.730418   1395653.352873            2.802           0.005
# L1.productA_sales_amount         0.784879         0.107554            7.298           0.000
# L1.productA_ad_cost             -0.534593         5.245509           -0.102           0.919
# L2.productA_sales_amount        -0.129469         0.134593           -0.962           0.336
# L2.productA_ad_cost             -0.355385         6.682107           -0.053           0.958
# L3.productA_sales_amount         0.139471         0.107782            1.294           0.196
# L3.productA_ad_cost             -1.702051         5.087110           -0.335           0.738
# ===========================================================================================
#
# Results for equation productA_ad_cost
# ===========================================================================================
#                               coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------
# const                        30980.510069     27602.421507            1.122           0.262
# L1.productA_sales_amount         0.003896         0.002127            1.831           0.067
# L1.productA_ad_cost              0.869184         0.103743            8.378           0.000
# L2.productA_sales_amount         0.000577         0.002662            0.217           0.828
# L2.productA_ad_cost             -0.414911         0.132155           -3.140           0.002
# L3.productA_sales_amount        -0.002497         0.002132           -1.171           0.241
# L3.productA_ad_cost              0.276491         0.100610            2.748           0.006
# ===========================================================================================
#
# Correlation matrix of residuals
#                          productA_sales_amount  productA_ad_cost
# productA_sales_amount                 1.000000          0.290731
# productA_ad_cost                      0.290731          1.000000
#
#
#
# グレンジャー因果性検定： productA_ad_cost -> productA_sales_amount 0.944254488549719

# %%
#VAR+グレンジャー因果性検定(productB)

#VAR
df = df_B[["productB_sales_amount", "productB_ad_cost"]]
maxlags = 5
var_model = VAR(df)
lag = var_model.select_order(maxlags).selected_orders
print("selectラグ", lag["aic"])
results = var_model.fit(lag["aic"])
print(results.summary())

# グレンジャー因果性検定
test_results = results.test_causality(causing=1, caused=0)
print("グレンジャー因果性検定：", df.columns[1], "->", df.columns[0], test_results.pvalue)

#グレンジャー因果性検定のp値が0.05を下回っているため、productBの広告の翌週以降の効果はありそう
#VARの係数をみると、前週の広告費の係数が1.84であるため、ROASは約200%。
# Out:
# selectラグ 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 20, Nov, 2025
# Time:                     09:31:18
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    45.4584
# Nobs:                     100.000    HQIC:                   45.3654
# Log likelihood:          -2542.89    FPE:                4.72571e+19
# AIC:                      45.3021    Det(Omega_mle):     4.45443e+19
# --------------------------------------------------------------------
# Results for equation productB_sales_amount
# ===========================================================================================
#                               coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------
# const                       106508.850167     39733.780360            2.681           0.007
# L1.productB_sales_amount         0.644207         0.085798            7.508           0.000
# L1.productB_ad_cost              1.066535         0.443741            2.404           0.016
# ===========================================================================================
#
# Results for equation productB_ad_cost
# ===========================================================================================
#                               coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------
# const                         3248.655704      4209.777811            0.772           0.440
# L1.productB_sales_amount         0.010481         0.009090            1.153           0.249
# L1.productB_ad_cost              0.908163         0.047014           19.317           0.000
# ===========================================================================================
#
# Correlation matrix of residuals
#                          productB_sales_amount  productB_ad_cost
# productB_sales_amount                 1.000000          0.346371
# productB_ad_cost                      0.346371          1.000000
#
#
#
# グレンジャー因果性検定： productB_ad_cost -> productB_sales_amount 0.017179892801663942

# %% [markdown]
# ## 分析の結論

# %% [markdown]
# ##### ・productAは広告をうった週のみ即時効果があり、、ROASは約6500%。継続効果はなし
# ##### ・productBは広告をうった即時効果としてはROASで500%程度だが、翌週に継続効果として+200%加算される合計でROAS700%程度の効果がある
